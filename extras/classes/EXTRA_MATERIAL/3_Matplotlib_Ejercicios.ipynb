# %% [markdown]
# # 1. Visualizar aleatoriamente 25 dígitos del conjunto de datos `MNIST`.

# %% [markdown]
# ### La base de datos `MNIST` (Modified National Institute of Standards and Technology (http://yann.lecun.com/exdb/mnist/, https://en.wikipedia.org/wiki/MNIST_database) es una gran base de datos de dígitos escritos a mano que se utiliza comúnmente para entrenar varios sistemas de procesamiento de imágenes y algoritmos de aprendizaje automático.

# %% [markdown]
# #### Ejecute el código de abajo (los detalles de la sintaxis se explicarán en el siguiente módulo, no son importantes ahora):

# %%
import numpy as np
import pandas as pd
df= pd.read_csv("https://raw.githubusercontent.com/mhemmg/datasets/master/mnist/mnist_test.csv")
mnist_array=df.to_numpy()

# %% [markdown]
# Este codigo creará una array numpy 2D: `mnist_array` con 10.000 filas y 785 columnas.

# %%
mnist_array.shape
# Out:
# (10000, 785)

# %% [markdown]
# Cada fila contiene 784 píxeles almacenados como un vector plano. Si este vector se convierte en una matriz de 28x28 píxeles, mostrará la imagen de un dígito. Si, por ejemplo, alguna fila en particular contiene una imagen del dígito `8` y se la convierte en una matriz de 28x28, da la siguiente imagen:

# %%
# a veces el color es importante (clasificación de las frutas)

import matplotlib.pyplot as plt
fig,ax=plt.subplots(1,1,figsize=(20,10))
ax.imshow(plt.imread('imgs/mnist_sample2.png'))
ax.set_axis_off()

# %% [markdown]
# #### En realidad, los elementos [1:785] de cada fila corresponden a la imagen de un dígito, y el elemento [0] de cada fila corresponde a la etiqueta del dígito. En este formato `mnist_array` contiene 10.000 imágenes de dígitos con las etiquetas.

# %% [markdown]
# ### La tarea es hacer una matriz de (5x5) imágenes de los dígitos elegidas al azar, donde cada imagen tenga un `título`! correspondiente a su etiqueta. Ejemplo de la matriz de las imágenes a continuación:

# %%
import matplotlib.pyplot as plt
fig,ax=plt.subplots(1,1,figsize=(8,8))
ax.imshow(plt.imread('imgs/mnist_array.png'))
ax.set_axis_off()

# %% [markdown]
# # 2. Haga una gráfica con tres curvas que muestren la dependencia de la radiación solar vs el tiempo.

# %% [markdown]
# ### Array Numpy `radiance_array` contiene irradiancia solar en Denver, Colorado del día 09.02.2022 medida para 3 diferentes canales de longitud de onda (la unidad de cada canal es milivolt: [mV]). La medición tomó 10 horas, desde las 7 a.m. hasta las 5 p.m. cada 20 segundos (1878 muestras). La primera columna de la matriz contiene el tiempo en segundos, la segunda columna contiene el valor de la tensión medida a 425 nm, la tercera columna contiene el valor de la tensión medida a 500 nm y la cuarta columna contiene el valor de la tensión medida a 610 nm del sensor. Consulte la tabla siguiente como referencia.

# %% [markdown]
# #### Ejecute el código de abajo (los detalles de la sintaxis no son importantes en este momento):

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df=pd.read_csv('https://raw.githubusercontent.com/mhemmg/datasets/master/radiation/radiation.csv')
radiance_array=df.to_numpy()
df.head()
# Out:
#    time [s]  425nm [mV]  500nm [mV]  610nm [mV]
# 0         0       2.024       2.241       5.445
# 1        20       2.024       2.263       5.565
# 2        40       2.537       7.486      39.396
# 3        60       2.630       9.613      85.020
# 4        80       2.692      11.067      95.041

# %%
radiance_array.shape
# Out:
# (1878, 4)

# %% [markdown]
# ### Hacer una gráfica con tres curvas que muestren la dependencia de la radiación solar de los tres canales vs el tiempo. La trama debe tener ciertas características:

# %% [markdown]
# #### a) La figura debe que tener tamaño 12x6 pulgadas.
#
# #### b) La figura debe tener título: `radiación vs tiempo`
#
# #### c) La curva correspondiente al sensor de 425nm debe ser: `negra, sólida, espesor: 2, etiqueta: '425nm'`.
#
# #### d) La curva correspondiente al sensor de 500nm debe ser: `azul, discontinua, espesor 2, etiqueta: '500nm'`.
#
# #### e) La curva correspondiente al sensor de 425nm debe ser: `roja, punteada, espesor 2, etiqueta: '610nm'`.
#
# #### f) La figura debe tener una leyenda correspondiente a las tres curvas.
#
# #### g) El eje X debe tener el nombre `Tiempo [s]`, el eje Y debe tener el nombre `Radiación [mV]`
#
# #### h) La parcela debe tener una cuadrícula (`grid`)
#
# #### i) Guarde la gráfica con el nombre `radiation_vs_time.jpg`

# %% [markdown]
# # 3. Elabore un gráfico de dispersión del precio de la casa vs el tamaño de la casa.

# %% [markdown]
# ### Array Numpy `price_size_array` contiene los precios de venta de las casas y los tamaños de estas casas en el condado de King, Estados Unidos. Las ventas incluyen las casas vendidas entre mayo de 2014 y mayo de 2015. La primera columna de la array contiene el precio de la casa en [USD] y la segunda columna contiene el valor según el tamaño de la casa en pies cuadrados [sq ft].

# %% [markdown]
# #### Ejecute el código de abajo (los detalles de la sintaxis no son importantes en este momento):

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df=pd.read_csv('https://raw.githubusercontent.com/mhemmg/datasets/master/housing/price_size_array.csv')
price_size_array=df.to_numpy()
df.head()
# Out:
#       price  size
# 0  221900.0  1180
# 1  538000.0  2570
# 2  180000.0   770
# 3  604000.0  1960
# 4  510000.0  1680

# %%
price_size_array.shape
# Out:
# (21612, 2)

# %% [markdown]
# ###  Haga un gráfico de dispersión de los precios de las casas vs los tamaños de las casas. La trama debe tener ciertas características:
#
# #### a) La figura debe tener como tamaño 8x6 pulgadas.
#
# #### b) La figura debe tener este título: `precio de la casa vs tamano`.
#
# #### c) Los puntos de dispersión deben tener `color rojo, tamaño = 1, etiqueta: 'datos'`.
#
# #### d) La figura debe tener una leyenda correspondiente al nombre los puntos.
#
# #### e) El eje X debe tener el nombre `Tamano [sqft]`, el eje Y debe tener el nombre `Precio [USD]`.
#
# #### f) La parcela debe tener una cuadrícula (`grid`).
#
# #### g) Guarde la gráfica con el nombre `casas_precio_vs_tamano.jpg`.

# %% [markdown]
# Revisado 14/5/2022 Luisa Gómez (Correctora de estilo)

# %% [markdown]
# # 4. Visualización de una array Numpy:
# Escribe un código que genere una matriz 3D (imagen RGB - Red Green Blue): 10x10x3 con valores aleatorios entre 0 y 256, y visualizarla. A continuación, cambie los valores de la primera capa de la tercera dimensión a cero y visualíce la array de nuevo. ¿Qué color falta en la nueva imagen?

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=4710cf8b-f7ec-43d1-a3bc-46d860c0e6af' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
