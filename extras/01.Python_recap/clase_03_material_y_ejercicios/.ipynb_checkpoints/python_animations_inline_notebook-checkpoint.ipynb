# %%
# %matplotlib notebook

import numpy as np
from matplotlib import pyplot as plt
from time import sleep

x=np.linspace(-2*np.pi,2*np.pi,100)
fig,ax=plt.subplots(1,1)

t=0.0
while True:
    ax.cla()
    ax.plot(x,np.cos(x-t),'-k')
    t=t+0.1
    fig.canvas.draw()
#    sleep(0.0)
# Out:
# <img src="data:image/png;base64,..." width="640">
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-77b3d4cd018b> in <module>
#      14     ax.plot(x,norm.pdf(x),'-k')
#      15     t=t+0.1
# ---> 16     fig.canvas.draw()
#      17 #    sleep(0.0)
#
# ~/.local/lib/python3.7/site-packages/matplotlib/backends/backend_webagg_core.py in draw(self)
#     186         self._png_is_old = True
#     187         try:
# --> 188             super().draw()
#     189         finally:
#     190             self.manager.refresh_all()  # Swap the frames.
#
# ~/.local/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     434              (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     435               else nullcontext()):
# --> 436             self.figure.draw(self.renderer)
#     437             # A GUI class may be need to update a window using this draw, so
#     438             # don't forget to call the superclass.
#
# ~/.local/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      71     @wraps(draw)
#      72     def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 73         result = draw(artist, renderer, *args, **kwargs)
#      74         if renderer._rasterizing:
#      75             renderer.stop_rasterizing()
#
# ~/.local/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# ~/.local/lib/python3.7/site-packages/matplotlib/figure.py in draw(self, renderer)
#    2809             self.patch.draw(renderer)
#    2810             mimage._draw_list_compositing_images(
# -> 2811                 renderer, self, artists, self.suppressComposite)
#    2812
#    2813             for sfig in self.subfigs:
#
# ~/.local/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130     if not_composite or not has_images:
#     131         for a in artists:
# --> 132             a.draw(renderer)
#     133     else:
#     134         # Composite any adjacent images together
#
# ~/.local/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# ~/.local/lib/python3.7/site-packages/matplotlib/axes/_base.py in draw(self, renderer)
#    3081
#    3082         mimage._draw_list_compositing_images(
# -> 3083             renderer, self, artists, self.figure.suppressComposite)
#    3084
#    3085         renderer.close_group('axes')
#
# ~/.local/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130     if not_composite or not has_images:
#     131         for a in artists:
# --> 132             a.draw(renderer)
#     133     else:
#     134         # Composite any adjacent images together
#
# ~/.local/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# ~/.local/lib/python3.7/site-packages/matplotlib/axis.py in draw(self, renderer, *args, **kwargs)
#    1156         renderer.open_group(__name__, gid=self.get_gid())
#    1157
# -> 1158         ticks_to_draw = self._update_ticks()
#    1159         ticklabelBoxes, ticklabelBoxes2 = self._get_tick_bboxes(ticks_to_draw,
#    1160                                                                 renderer)
#
# ~/.local/lib/python3.7/site-packages/matplotlib/axis.py in _update_ticks(self)
#    1045         major_locs = self.get_majorticklocs()
#    1046         major_labels = self.major.formatter.format_ticks(major_locs)
# -> 1047         major_ticks = self.get_major_ticks(len(major_locs))
#    1048         self.major.formatter.set_locs(major_locs)
#    1049         for tick, loc, label in zip(major_ticks, major_locs, major_labels):
#
# ~/.local/lib/python3.7/site-packages/matplotlib/axis.py in get_major_ticks(self, numticks)
#    1373         while len(self.majorTicks) < numticks:
#    1374             # Update the new tick label properties from the old.
# -> 1375             tick = self._get_tick(major=True)
#    1376             self.majorTicks.append(tick)
#    1377             self._copy_tick_props(self.majorTicks[0], tick)
#
# ~/.local/lib/python3.7/site-packages/matplotlib/axis.py in _get_tick(self, major)
#    2323         else:
#    2324             tick_kw = self._minor_tick_kw
# -> 2325         return YTick(self.axes, 0, major=major, **tick_kw)
#    2326
#    2327     def set_label_position(self, position):
#
# ~/.local/lib/python3.7/site-packages/matplotlib/axis.py in __init__(self, *args, **kwargs)
#     492         self.label2.set(
#     493             x=1, y=0,
# --> 494             verticalalignment=va, horizontalalignment=ha, transform=trans,
#     495         )
#     496
#
# ~/.local/lib/python3.7/site-packages/matplotlib/artist.py in <lambda>(self, **kwargs)
#     114             return
#     115
# --> 116         cls.set = lambda self, **kwargs: Artist.set(self, **kwargs)
#     117         cls.set.__name__ = "set"
#     118         cls.set.__qualname__ = f"{cls.__qualname__}.set"
#
# ~/.local/lib/python3.7/site-packages/matplotlib/artist.py in set(self, **kwargs)
#    1162         # module.
#    1163         kwargs = cbook.normalize_kwargs(kwargs, self)
# -> 1164         return self.update(kwargs)
#    1165
#    1166     @contextlib.contextmanager
#
# ~/.local/lib/python3.7/site-packages/matplotlib/text.py in update(self, kwargs)
#     170         # Update bbox last, as it depends on font properties.
#     171         bbox = kwargs.pop("bbox", sentinel)
# --> 172         super().update(kwargs)
#     173         if bbox is not sentinel:
#     174             self.set_bbox(bbox)
#
# ~/.local/lib/python3.7/site-packages/matplotlib/artist.py in update(self, props)
#    1064                         raise AttributeError(f"{type(self).__name__!r} object "
#    1065                                              f"has no property {k!r}")
# -> 1066                     ret.append(func(v))
#    1067         if ret:
#    1068             self.pchanged()
#
# ~/.local/lib/python3.7/site-packages/matplotlib/text.py in set_horizontalalignment(self, align)
#     965         _api.check_in_list(['center', 'right', 'left'], align=align)
#     966         self._horizontalalignment = align
# --> 967         self.stale = True
#     968
#     969     def set_multialignment(self, align):
#
# ~/.local/lib/python3.7/site-packages/matplotlib/artist.py in stale(self, val)
#     295         # draw stack and is not expected to be drawn as part of the normal
#     296         # draw loop (when not saving) so do not propagate this change
# --> 297         if self.get_animated():
#     298             return
#     299
#
# ~/.local/lib/python3.7/site-packages/matplotlib/artist.py in get_animated(self)
#     832     def get_animated(self):
#     833         """Return whether the artist is animated."""
# --> 834         return self._animated
#     835
#     836     def get_in_layout(self):
#
# KeyboardInterrupt:

# %%
# %matplotlib notebook

import numpy as np
from matplotlib import pyplot as plt
from time import sleep

time_lap=[0]
value=[0]
t=1.0
fig,ax=plt.subplots(1,1)

while True:
#    ax.cla()
    ax.plot(time_lap,value,'-k')
    fig.canvas.draw()
    sleep(t)
    time_lap.append(time_lap[-1]+t)
    value.append(np.random.uniform(0,1))

# %%
gaussian_distribution = np.random.normal(0,0.1,100)
