# %% [markdown]
# # Ejercicios sobre números

# %% [markdown]
# ## 1. Construya una función `celsius_fahrenheit_1(celsius)`, que reciba un valor numérico de temperatura en centígrados y devuelva una temperatura en escala Fahrenheit.

# %% [markdown]
# #### Por ejemplo:
# `celsius_fahrenheit_1(20.22)` tiene que devolver valor `68.396`
# `celsius_fahrenheit_1(0)` tiene que devolver valor float `32.0`

# %%
#Manuela Montoya Gonzalez
#cc: 1017260561

# %%
#Primer punto
#Funcion celsius-fahrenheit 
def celsius_fahrenheit_1(celsius):
  fahrenheit = float(9/5*(celsius) + 32)
  return(fahrenheit)

# %%
celsius_fahrenheit_1(0)
# Out:
# 32.0

# %% [markdown]
# ## 2. Modifique la función anterior para devolver `None` en caso de cualquier error e imprimir mensaje `error`.

# %%
#Segundo punto
#Modifique la función anterior para devolver None en caso de cualquier error
#limite la escala c que va desdes -273.15 a 100 celsius
def celsius_fahrenheit_1(celsius):
  try:
    if (-273.15<=celsius<=100):
      fahrenheit = float(9/5*(celsius) + 32)
      return(fahrenheit)
    else:
      celsius = None
      if celsius is None:
        print ('error')
#si ingresan algun string o list la funcion arroja error
  except: 
    if (celsius == str, list):
      celsius = None
      if celsius is None:
        print ('error')

# %% [markdown]
# ![tem.webp](data:image/webp;base64,...)

# %%
#valor maximo que pasa a fahrenheit (100 celsius)
celsius_fahrenheit_1(100)
# Out:
# 212.0

# %%
#si sobrepasa los 100 celsius imprime error
celsius_fahrenheit_1(101)
# Out:
# error

# %%
#si es mayor o igual a -273.15 celsius pertenece a la escala
celsius_fahrenheit_1(-273.15)
# Out:
# -459.66999999999996

# %%
#si es menor a -273.15 celsius no pertenece a la escala
celsius_fahrenheit_1(-273.16)
# Out:
# error

# %%
celsius_fahrenheit_1('hello profesor')
# Out:
# error

# %% [markdown]
# #### Por ejemplo:
# `celsius_fahrenheit_2('hello')` tiene que devolver valor None

# %% [markdown]
# ## 3. Construya una función `sum_odd_even(a)`, que para un número dado `a` devuelva dos valores: la suma de todos los números pares y la suma de los números impares dentro del rango de `a` (pista: usa loop `for`)
#
# (en inglés ***odd*** significa impar y ***even*** significa par)

# %%
#tercer punto
#función sum_odd_even(a), que para un número dado a devuelva dos valores: la suma de todos los números pares y la suma de los números impares dentro del rango de a
def sum_odd_even(a):
  sum_even = 0
  sum_odd = 0
  for i in range(0,a):
    if (i % 2 == 0):
      sum_even = sum_even + i 

    if (i % 2 == 1):
      sum_odd= sum_odd + i
  return sum_odd, sum_even

# %%
sum_odd_even(10)
# Out:
# (25, 20)

# %% [markdown]
# #### Por ejemplo:
# `sum_odd, sum_even = sum_odd_even(10)`  tiene que devolver valores:  25,20

# %% [markdown]
# ## 4. La función $\frac{1}{1-x}$ se puede aproximar con la siguiente suma:

# %% [markdown]
# $$\frac{1}{1-x}=\sum_{k=0}^{\infty}x^k$$

# %% [markdown]
# Donde 'k' es el número de los términos de la suma, responsable de cuán buena será la aproximación, si k=2 la aproximación es peor que si k=5...

# %% [markdown]
# Construya una función `div_x(x,k)` que acepte dos parámetros `x` y `k` y devuelva valor de aproximación de función $\frac{1}{1-x}$.

# %%
#cuarto punto
#Construya una función div_x(x,k) que acepte dos parámetros x y k y devuelva valor de aproximación de función 1/(1-x)
#funcion aproximacion
def div_x(x,k):
  approx = 0
  for i in range(0,k):
    approx += float(x**(i))
  return approx

#funcion 
def div_x1(x):
     div = 1/(1-x)
     return div

# %%
#aproximacion serie de Taylor
div_x(0.2,10)
# Out:
# 1.249999872

# %%
#aproximacion serie de Taylor
div_x(0.2,2)
# Out:
# 1.2

# %%
#funcion
div_x1(0.2)
# Out:
# 1.25

# %% [markdown]
# ###### Por ejemplo:
# `div_x_approx = div_x(0.2,2)` devuelve: `1.2`
# `div_x_approx = div_x(0.2,10)` devuelve: `1.249999872`
#
# Puede comparar su aproximación con resultados de operación directa: $\frac{1}{1-x}$
#
# *Esta aproximación con suma se llama Taylor expansion.
