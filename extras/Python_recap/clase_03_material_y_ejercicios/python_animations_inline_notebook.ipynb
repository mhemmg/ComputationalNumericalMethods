# %%
# %matplotlib notebook

import numpy as np
from matplotlib import pyplot as plt
from time import sleep

x=np.linspace(-2*np.pi,2*np.pi,100)
fig,ax=plt.subplots(1,1)

t=0.0
while True:
    ax.cla()
    ax.plot(x,np.cos(x-t),'-k')
    t=t+0.1
    fig.canvas.draw()
#    sleep(0.0)
# Out:
# <img src="data:image/png;base64,..." width="639.4">
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-c2272da8ece9> in <module>
#      13     ax.plot(x,np.cos(x-t),'-k')
#      14     t=t+0.1
# ---> 15     fig.canvas.draw()
#      16 #    sleep(0.0)
#
# /usr/lib64/python3.7/site-packages/matplotlib/backends/backend_webagg_core.py in draw(self)
#     151             super().draw()
#     152         finally:
# --> 153             self.manager.refresh_all()  # Swap the frames.
#     154
#     155     def draw_idle(self):
#
# /usr/lib64/python3.7/site-packages/matplotlib/backends/backend_webagg_core.py in refresh_all(self)
#     441     def refresh_all(self):
#     442         if self.web_sockets:
# --> 443             diff = self.canvas.get_diff_image()
#     444             if diff is not None:
#     445                 for s in self.web_sockets:
#
# /usr/lib64/python3.7/site-packages/matplotlib/backends/backend_webagg_core.py in get_diff_image(self)
#     199             buff = _png.write_png(
#     200                 output.view(dtype=np.uint8).reshape(output.shape + (4,)),
# --> 201                 None, compression=6, filter=_png.PNG_FILTER_NONE)
#     202
#     203             # Swap the renderer frames
#
# KeyboardInterrupt:

# %%
# %matplotlib notebook

import numpy as np
from matplotlib import pyplot as plt
from time import sleep

time_lap=[0]
value=[0]
t=1.0
fig,ax=plt.subplots(1,1)

while True:
    ax.cla()
    ax.plot(time_lap,value,'-k')
    fig.canvas.draw()
    sleep(t)
    time_lap.append(time_lap[-1]+t)
    value.append(np.random.uniform(0,1))
# Out:
# <img src="data:image/png;base64,..." width="639.4">
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-7d9735be0f2c> in <module>
#      14     ax.plot(time_lap,value,'-k')
#      15     fig.canvas.draw()
# ---> 16     sleep(t)
#      17     time_lap.append(time_lap[-1]+t)
#      18     value.append(np.random.uniform(0,1))
#
# KeyboardInterrupt:

# %%
gaussian_distribution = np.random.normal(0,0.1,100)
