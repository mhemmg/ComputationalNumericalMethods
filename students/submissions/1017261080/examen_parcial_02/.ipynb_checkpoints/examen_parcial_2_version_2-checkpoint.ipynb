# %% [markdown]
# # Examen parcial 2 (raizes y ~interpolacion)
# * Antes de enviar el archivo, $\textbf{reiniciar y ejecutar el kernel}$ para ver que el archivo se compila sin errores
# * enviar el archivo jupyter sin anexos antes de las 10.10am del 04.03.2022 a mi dirección de correo electrónico: michal.hemmerling@udea.edu.co

# %% [markdown]
# # Ejercicio

# %% [markdown]
# Bajo ciertas condiciones, los dispositivos ópticos como los láseres pueden mostrar un comportamiento complejo en el perfil del rayo de luz.
#
#
# <table><tr>
# <td> <img src="nonlinear_behaviour.png" width="600" /> </td>
# </tr></table>
#
# Para un dispositivo óptico particular que consiste en un medio no lineal dentro de una cavidad óptica, esto sólo ocurre cuando la intensidad I se encuentra dentro de un cierto rango que está dado por la ecuación:
#
# $$f(x)=(x+1)^2 - c(x-1) < 0 $$
#
# donde $x$ es la intensidad del campo eléctrico y $c$ es la fuerza de la absorción del
# medio no lineal.

# %% [markdown]
# ## 1.
# Cree una función llamada `f_cost` que reciba dos parámetros (x,c) y solo devuelva la función f(x) como se mencionó anteriormente.

# %%
# tu codigo:
def f_cost(x,c):
    y = (x+1)**2 -c*(x-1)
    return y

# %% [markdown]
# ## 2.
# Usando funcion `f_cost` haz un gráfico con cuatro curvas para c=5,10,15,20 y con x entre -10,20 (50 puntos)
# * hacer que cada curva sea de un color diferente
# * añadir etiquetas

# %%
# tu codigo:
# Importing libraries
import numpy as np
import matplotlib.pyplot as plt

# %%
C = [5,10,15,20] # Parameters array
x = np.linspace(-10,20,50) # Values 
Label = ['5',' 10','15','20'] # Labels
Color=['red','black','blue','gray'] #Colors

#Graficación
plt.figure(figsize=(12,5))
plt.title('Gráfica de la función', fontsize='15')
for i in range(0,4):
    plt.plot(x,f_cost(x,C[i]),label ='$f(x)$;c = '+Label[i],color=Color[i])
plt.grid()
plt.legend(fontsize='13')
plt.xlabel('$x$ values',fontsize='13',)
plt.ylabel('$f(x)$',fontsize='13')
# Out:
# Text(0, 0.5, '$f(x)$')

# %% [markdown]
# ## 2a. Para cual `c` esta funcion no tiene raices?

# %% [markdown]
# ### tu respuesta
#
# Para el valor de $c = 5$ no se encuentran las raíces de esa función

# %% [markdown]
# ## 3.
# Cree una función llamada `root_finding()` que devuelva el valor de la raíz (si existiera) para cada parametro `c` (pense `Newton` o `bisecion`). Usando esta funcion vamos a buscar primero raiz izquierda y despues raiz derecha.

# %%
import scipy.optimize as optimize

# %%
# tu codigo:
C = [5,10,15,20] # Parameters array
# Usando método de Newton 
def root_finding(f_cost,start,C):
    roots = []
    for i in range(0,4):
        try:
            root = optimize.newton(f_cost, start,args=(C[i],))
            print(root)
            
        except:
            root=np.nan

# %%
print('Para la raíz izquierda')
print(root_finding(f_cost,2,C))
# Out:
# Para la raíz izquierda
# 1.7639320225002109
# 1.3765246170202043
# 1.2540333075851664
# None

# %%
print('Para la raíz derecha')
root_finding(f_cost,30,C)
# Out:
# Para la raíz derecha
# 6.236067977499788
# 11.623475382979798
# 16.745966692414832

# %% [markdown]
# ## 4a.
# Primero vamos a mirar el comportamiento de raiz de lado izquierda: Defina el vector `c_vec` que contiene 50 valores de 5 a 100. En el loop, llame a la función `root_finding()` para cada valor `c` en el vector `c_vec`. Guarda los resultados en variable `left_roots`

# %%
# tu codigo:
left_roots = []
#c = [0]
c_vec = np.linspace(5,100,50)
for c in c_vec:
    try:
        root = root_finding(f_cost,-100,c)
    except:
        root=np.nan
        
    left_roots.append(root)

# %%
left_roots
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %% [markdown]
# ## 4b
# Hacer un gráfico de raíz izquierda vs c

# %%
# tu codigo:
fig,ax = plt.subplots(1,1)
#ax.plot(c_vec,results,'.k')
ax.scatter(c_vec,left_roots[0],c='r')
ax.grid('True')
ax.set_xlabel('C')
ax.set_ylabel('root')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-4a07793e246a> in <module>
#       2 fig,ax = plt.subplots(1,1)
#       3 #ax.plot(c_vec,results,'.k')
# ----> 4 ax.scatter(c_vec,left_roots[0],c='r')
#       5 ax.grid('True')
#       6 ax.set_xlabel('C')
#
# ~/.local/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1410     def inner(ax, *args, data=None, **kwargs):
#    1411         if data is None:
# -> 1412             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1413
#    1414         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/.local/lib/python3.7/site-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, **kwargs)
#    4367         y = np.ma.ravel(y)
#    4368         if x.size != y.size:
# -> 4369             raise ValueError("x and y must be the same size")
#    4370
#    4371         if s is None:
#
# ValueError: x and y must be the same size

# %% [markdown]
# ## 5a.
# Ahora vamos a mirar el comportamiento de raiz de lado derecha: Defina el vector `c_vec` que contiene 50 valores de 5 a 100. En el loop, llame a la función `root_finding()` para cada valor `c` en el vector `c_vec`. Guarda los resultados en variable `right_roots`.

# %%
# tu codigo:
right_roots= []
for C in c_vec:
    try:
        root = root_finding(f_cost,30,C)
    except:
        root=np.nan
        
    right_roots.append(root)
print(right_roots)
# Out:
# 4.834349223474427
# 4.834349223474427
# 4.834349223474427
# 4.834349223474427
# 7.167796727014774
# 7.167796727014774
# 7.167796727014774
# 7.167796727014774
# 9.271514674100445
# 9.271514674100445
# 9.271514674100445
# 9.271514674100445
# 11.305744505628551
# 11.305744505628551
# 11.305744505628551
# 11.305744505628551
# 13.307651996760457
# 13.307651996760457
# 13.307651996760457
# 13.307651996760457
# 15.291542762993839
# 15.291542762993839
# 15.291542762993839
# 15.291542762993839
# 17.264266148530055
# 17.264266148530055
# 17.264266148530055
# 17.264266148530055
# 19.22955570322865
# 19.22955570322865
# 19.22955570322865
# 19.22955570322865
# 21.189633626735635
# 21.189633626735635
# 21.189633626735635
# 21.189633626735635
# 23.1459103561492
# 23.1459103561492
# 23.1459103561492
# 23.1459103561492
# 25.099326379404445
# 25.099326379404445
# 25.099326379404445
# 25.099326379404445
# 27.05053391601525
# 27.05053391601525
# 27.05053391601525
# 27.05053391601525
# 28.999999999999996
# 28.999999999999996
# 28.999999999999996
# 28.999999999999996
# 30.948068111096056
# 30.948068111096056
# 30.948068111096056
# 30.948068111096056
# 32.89499664356202
# 32.89499664356202
# 32.89499664356202
# 32.89499664356202
# 34.84098380009606
# 34.84098380009606
# 34.84098380009606
# 34.84098380009606
# 36.78618420433618
# 36.78618420433618
# 36.78618420433618
# 36.78618420433618
# 38.73072028520036
# 38.73072028520036
# 38.73072028520036
# 38.73072028520036
# 40.67469026135113
# 40.67469026135113
# 40.67469026135113
# 40.67469026135113
# 42.61817385666851
# 42.61817385666851
# 42.61817385666851
# 42.61817385666851
# 44.56123646641425
# 44.56123646641425
# 44.56123646641425
# 44.56123646641425
# 46.50393224374629
# 46.50393224374629
# 46.50393224374629
# 46.50393224374629
# 48.44630642002321
# 48.44630642002321
# 48.44630642002321
# 48.44630642002321
# 50.38839707232806
# 50.38839707232806
# 50.38839707232806
# 50.38839707232806
# 52.330236486202445
# 52.330236486202445
# 52.330236486202445
# 52.330236486202445
# 54.27185221791056
# 54.27185221791056
# 54.27185221791056
# 54.27185221791056
# 56.213267930881464
# 56.213267930881464
# 56.213267930881464
# 56.213267930881464
# 58.15450406048505
# 58.15450406048505
# 58.15450406048505
# 58.15450406048505
# 1.0676869591920632
# 1.0676869591920632
# 1.0676869591920632
# 1.0676869591920632
# 1.0655345504635683
# 1.0655345504635683
# 1.0655345504635683
# 1.0655345504635683
# 1.0635149476465406
# 1.0635149476465406
# 1.0635149476465406
# 1.0635149476465406
# 1.0616162158746472
# 1.0616162158746472
# 1.0616162158746472
# 1.0616162158746472
# 1.0598278099956056
# 1.0598278099956056
# 1.0598278099956056
# 1.0598278099956056
# 1.058140377852194
# 1.058140377852194
# 1.058140377852194
# 1.058140377852194
# 1.0565455960845753
# 1.0565455960845753
# 1.0565455960845753
# 1.0565455960845753
# 1.0550360323451151
# 1.0550360323451151
# 1.0550360323451151
# 1.0550360323451151
# 1.0536050290948538
# 1.0536050290948538
# 1.0536050290948538
# 1.0536050290948538
# 1.052246605135765
# 1.052246605135765
# 1.052246605135765
# 1.052246605135765
# 1.0509553717967868
# 1.0509553717967868
# 1.0509553717967868
# 1.0509553717967868
# 1.049726461289723
# 1.049726461289723
# 1.049726461289723
# 1.049726461289723
# 1.0485554652208315
# 1.0485554652208315
# 1.0485554652208315
# 1.0485554652208315
# 1.0474383816164656
# 1.0474383816164656
# 1.0474383816164656
# 1.0474383816164656
# 1.0463715691176918
# 1.0463715691176918
# 1.0463715691176918
# 1.0463715691176918
# 1.0453517072363823
# 1.0453517072363823
# 1.0453517072363823
# 1.0453517072363823
# 1.0443757617568101
# 1.0443757617568101
# 1.0443757617568101
# 1.0443757617568101
# 1.0434409545214791
# 1.0434409545214791
# 1.0434409545214791
# 1.0434409545214791
# 1.0425447369662688
# 1.0425447369662688
# 1.0425447369662688
# 1.0425447369662688
# 1.0416847668728046
# 1.0416847668728046
# 1.0416847668728046
# 1.0416847668728046
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]

# %% [markdown]
# ## 5b
# * Hacer un gráfico de raíz derecha vs c

# %%
# tu codigo:

# %% [markdown]
# ## 6.
# Pregunta:
# * este cierto *rango* para cual se obtiene un comportamiento complejo esta convergente o divergente cuando `c` es creciente
# * si este rango esta convergiendo, ¿a qué valor?
# * si este rango esta divergente, como esta divergente (lineal, cuadrático, diferente)

# %%
# respuesta:
#
#
#
#
#

# %% [markdown]
# # Feedback:
#
# `Correct implementation of the f_cost function + labeled plot 	  (max 2.0p):	2.0p`
# `Correct implementation of the root finding function 		       (max 2.0p):	2.0p`
# `Correct result of the evolution of the left roots (+ plot)	     (max 2.0p):	1.0p`
# `Correct result of the evolution of the right roots (+ plot)	    (max 2.0p):	1.0p`
# `Correct conclusion of the range behavious			              (max 2.0p):	0.0p`
#
# `- Total:                                                          (max 10.0p):   6.0p`

# %% [markdown]
# #### Comments:
#
# Error esta aqui:
# Usted defino su funcion root_finding y argumento C usted paso como vector c[i]
#             root = optimize.newton(f_cost, start,args=(C[i],))
#
# Pero aqui c no es vector pero un float:
#
# for C in c_vec:
#     try:
#         root = root_finding(f_cost,30,C)
