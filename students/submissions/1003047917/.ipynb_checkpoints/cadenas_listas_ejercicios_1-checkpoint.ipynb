# %%
# LEEME
# Despues de ejecutar este codigo los resultados aparecen en la celula abajo
# verifica sus respuestas!


# Ejemplo
# para una cadena dada, devuelva una nueva cadena hecha de 
# primer y último carácter 
# si la cadena tiene menos que dos caracteres devuelva la nueva cadena con solo el primer carácter
# si la cadena es vacia devuelve cadena vacia

def first_last(some_string):
    if len(some_string)==0: #Si some_string tiene 0 carácteres 
        result='' #devolvemos cadena vacía
    if len(some_string)==1: #Si la cadena tiene menos de 2 carácteres
        result=some_string[0] #Devolvemos primer caracter
    if len(some_string)>1: #Si tiene más de 1 caracter 
        result=some_string[0]+some_string[-1] #devolvemos primer y ultimo caracter
    return result #return result

# A. donas
# Dado un numero entero integer de un número de donas, devuelva una cadena
# de la forma 'Numero de donas: <count>', donde <count> es el número
# Sin embargo, si el recuento es 10 o más, use la palabra 'muchos'
# Entonces donuts(5) devuelve 'Numero de donas: 5'
# y donuts(23) devuelve 'Numero de donas: muchos

def donuts(count):
  # +++ su codigo aqui +++
    if type(count)==int: #si count es una variable int
    #----------------------------------------------------------
        if count < 10: #si count es menor que 10
            donuts = 'Numbero de donas: '+ str(count) #devolver 'numbero de donas: x'
        else: #si count es mayor o igual que 10
            donuts = 'Numbero de donas: muchos' #devolver 'Numbero de donas: muchos'
    #-----------------------------------------------------------
    else: #si count no es variable int
        print('error: variable has to be integer')
    #----------------------------------------------------------- 
    return donuts #return donuts


# B. both_ends
# Dada una cadena s, devuelve una cadena hecha de las primeras 2
# y los últimos 2 caracteres de la cuerda original,
# así que 'spring' produce 'spng'. Sin embargo, 
# si la longitud de la cadena es menor que 2, 
# devuelva en su lugar la cadena vacía.
def both_ends(s):
  # +++ su codigo aqui +++
    try: #intenta
    #----------------------------------------------
        if len(s) < 2: #si s tiene 1 o 0 carácteres
            cadena = '' #devolver cadena vacía
        else: #si s tiene más de 1 caracter
            cadena = s[0]+s[1]+s[-2]+s[-1] #devolver cadena = 2 primeros caracteres + 2 ultimos caracteres
    #----------------------------------------------
    except: #si hay un error
        print('variable has to be a string') #imprime mensaje de error
    #----------------------------------------------
    return cadena


# C. fix_start
# Dada una cadena s, devuelve una cadena
# donde todas las ocurrencias de su primer caracter tienen
# se ha cambiado a '*', excepto que no cambie el primer char en sí.
# por ejemplo, 'babble' produce 'ba**le'
# Supongamos que la cadena tiene una longitud 1 o superior.
# Sugerencia: s.replace(stra, strb) devuelve una versión de string s
# donde todas las instancias de stra han sido reemplazadas por strb.
def fix_start(s):
  # +++ su codigo aqui +++
    try: #intenta
    #----------------------------------------------
    #ocurrencias = repeticiones -> '*'
    #--------------------------- -------------------
        cadena = s[0] #definimos variable cadena = primer caracter de s
        for i in range(1,len(s)): #para cada caracter de s
            if s[i] == s[0]: #si ese caracter es igual al primer caracter 
                cadena += '*' #añade '*' a cadena
            else: #si no es igual al primer caracter
                cadena += s[i] #añade el caracter a cadena
    #----------------------------------------------
    except: #si hay un error
        print('variable has to be a string') #imprime mensaje de error
    #----------------------------------------------
    return cadena 


# D. MixUp
# Dadas las cadenas a y b, devuelve una sola cadena con a y b separadas
# por un espacio '<a> <b>', excepto intercambiar los primeros 2 caracteres de cada cadena.
# por ejemplo.
#   'mix', pod' -> 'pox mid'
#   'dog', 'dinner' -> 'dig donner'
# Supongamos que a y b son de longitud 2 o más.
def mix_up(a, b):
  # +++ su codigo aqui +++
    try: #intenta
    #----------------------------------------------
        new_a = b[0]+b[1] #definimos string new_a = dos primeros caracteres de b 
        new_b = a[0]+a[1] #definimos string new_b = dos primeros caracteres de a 
    #----------------------------------------------
        new_a += a[2:] #le concatenamos la parte restante de a
        new_b += b[2:] #le concatenamos la parte restante de b
    #----------------------------------------------
        cadena = new_a + ' ' + new_b #cadena = '<a> <b>'
    #------------------------------------------------------
    except: #si hay un error
        print('variable has to be a string') #imprime mensaje de error
    #----------------------------------------------
    return cadena


# E. front_back
# Considere dividir una cadena en dos mitades.
# Si la longitud es par, las mitades delantera y trasera tienen la misma longitud.
# Si la longitud es impar, diremos que el caracter extra va en la mitad delantera.
# por ejemplo, 'abcde', la mitad delantera es 'abc', la mitad trasera 'de'.
# Dadas 2 cadenas, a y b, devuelven una cadena de la forma
# a-front + b-front + a-back + b-back
# ejemplo si dos cadenas son pares: a='xyzt', b='abcd'. result='xyabztcd'

def front_back(a, b):
  # +++ su codigo aqui +++
    try: #intenta
        import math
    # abcd --> [0][1][2][3] len()= 4 -> /2 -> 2 -> ceil () --> 2 -> [1]
    #abcde --> [0][1][2][3][4] len() = 5 -> /2 -> 2.5 -> ceil() --> 3 -> [2]
    #-------------------------------------------------------
        i = math.ceil(len(a)/2) #numero de caracteres de la parte delantera
        j = math.ceil(len(b)/2) #numero de caracteres de la parte delantera
    #-------------------------------------------------------
        a_front = a[0:i] #desde a[0] hasta a[i-1] 
        a_back = a[i:] #cerrado en i hasta a[-1]
        b_front = b[0:j] #desde b[0] hasta b[j-1] 
        b_back = b[j:] #cerrado en j hasta b[-1]
    #-------------------------------------------------------
        cadena = a_front + b_front + a_back + b_back #cadena = formula dada
    except: #si hay un error
        print('variable has to be a string') #imprime mensaje de error
    #----------------------------------------------
    return cadena

# Desafío
# F. Extraer el valor del tiempo (time=...) como float de una cadena
# conversion se hace usando float(14) que devuelve 14.0
# recuerda que el valor del tiempo puede tener formato de dos digitos o tres digitos como
# dd.dd o ddd.d o dd.dd... pero siempre terminará con la cadena 'ms'
# ejemplo de cadena: 
# '64 bytes de bogota.net (172.217.173.36): ttl=117 time=14.4 ms'
def extract_time(s):
  # +++ su codigo aqui +++
    #recibimos cadena s
    lista_1 = s.split() #lista_1 = lista de palabras de s
    #------------------------------------------------------------------------
    for i in range(0,len(lista_1)): #como 'time=...' va acompañado de 'ms' 
        #--------------------------------------------------------------------
        if lista_1[i] == 'ms': #encontraremos 'ms'
            tiempo = lista_1[i-1] #y 'time=...'' será el elemento anterior
        #---------------------------------------------------------------------
    text_number = tiempo.split('=') #'time=x' -> [time,x]
    time = float(text_number[1]) #nos interesa x, segundo elemento de text_number
    #lo convertimos en float
    return time














# DO NOT EDIT BELOW
#############################################################################################################################################
#############################################################################################################################################
# Provided simple test() function used in main() to print
# what each function returns vs. what it's supposed to return.
def test(got, expected):
  if got == expected:
    prefix = ' OK '
  else:
    prefix = '  X '
  print('%s got: %s expected: %s' % (prefix, repr(got), repr(expected)))


# Provided main() calls the above functions with interesting inputs,
# using test() to check if each result is correct or not.
def main():
    
  print('example')
  test(first_last('H'), 'H')
  test(first_last('what an amazing day'), 'wy')
  test(first_last(''), '')

  print('donuts')
  # Each line calls donuts, compares its result to the expected for that call.
  test(donuts(4), 'Numbero de donas: 4')
  test(donuts(9), 'Numbero de donas: 9')
  test(donuts(10), 'Numbero de donas: muchos')
  test(donuts(99), 'Numbero de donas: muchos')

  print
  print('both_ends')
  test(both_ends('spring'), 'spng')
  test(both_ends('Hello'), 'Helo')
  test(both_ends('a'), '')
  test(both_ends('xyz'), 'xyyz')

  
  print
  print('fix_start')
  test(fix_start('babble'), 'ba**le')
  test(fix_start('aardvark'), 'a*rdv*rk')
  test(fix_start('google'), 'goo*le')
  test(fix_start('donut'), 'donut')

  print
  print('mix_up')
  test(mix_up('mix', 'pod'), 'pox mid')
  test(mix_up('dog', 'dinner'), 'dig donner')
  test(mix_up('gnash', 'sport'), 'spash gnort')
  test(mix_up('pezzy', 'firm'), 'fizzy perm')

  print
  print('front_back')
  test(front_back('abcd', 'xy'), 'abxcdy')
  test(front_back('abcde', 'xyz'), 'abcxydez')
  test(front_back('Kitten', 'Donut'), 'KitDontenut')

  print
  print('extract')
  test(extract_time('64 bytes from bog02s12-in-f4.1e100.net (172.217.173.36): icmp_seq=1 ttl=117 time=14.4 ms'), 14.4)
  test(extract_time('64 bytes from bog02s12-in-f4.1e100.net (172.217.173.36): icmp_seq=1 ttl=1147 time=1250.42 ms'), 1250.42)
  test(extract_time('64 bytes from bog02s12-in-.net (172.217.173.36): icmp_seq=1 ttl=1217 time=25.1 ms google statistics'), 25.1)


# Standard boilerplate to call the main() function.
if __name__ == '__main__':
  main()
# Out:
# example
#  OK  got: 'H' expected: 'H'
#  OK  got: 'wy' expected: 'wy'
#  OK  got: '' expected: ''
# donuts
#  OK  got: 'Numbero de donas: 4' expected: 'Numbero de donas: 4'
#  OK  got: 'Numbero de donas: 9' expected: 'Numbero de donas: 9'
#  OK  got: 'Numbero de donas: muchos' expected: 'Numbero de donas: muchos'
#  OK  got: 'Numbero de donas: muchos' expected: 'Numbero de donas: muchos'
# both_ends
#  OK  got: 'spng' expected: 'spng'
#  OK  got: 'Helo' expected: 'Helo'
#  OK  got: '' expected: ''
#  OK  got: 'xyyz' expected: 'xyyz'
# fix_start
#  OK  got: 'ba**le' expected: 'ba**le'
#  OK  got: 'a*rdv*rk' expected: 'a*rdv*rk'
#  OK  got: 'goo*le' expected: 'goo*le'
#  OK  got: 'donut' expected: 'donut'
# mix_up
#  OK  got: 'pox mid' expected: 'pox mid'
#  OK  got: 'dig donner' expected: 'dig donner'
#  OK  got: 'spash gnort' expected: 'spash gnort'
#  OK  got: 'fizzy perm' expected: 'fizzy perm'
# front_back
#  OK  got: 'abxcdy' expected: 'abxcdy'
#  OK  got: 'abcxydez' expected: 'abcxydez'
#  OK  got: 'KitDontenut' expected: 'KitDontenut'
# extract
#  OK  got: 14.4 expected: 14.4
#  OK  got: 1250.42 expected: 1250.42
#  OK  got: 25.1 expected: 25.1
