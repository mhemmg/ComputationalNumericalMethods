# %% [markdown]
# <p>
# <img src="https://drive.google.com/uc?id=15e9jqlH6r33n0cd5s9LQGCmVg3gzlyNN" align="left" width="250" height="300" >
# <br>
# <h1><b><center> Metodos Computacionales </center></b></h1>
# <h2><b><center>Parcial 2</center></b><h2>
# <h3><i><center>Juanita Andrea Agudelo</center></i><h2>
# <h3><i><center>1000722415</center></i><h2>
# <h5><b><center>4 Marzo 2022</center></b><h5>

# %% [markdown]
# # Examen parcial 2 (raizes y ~interpolacion)
# * Antes de enviar el archivo, $\textbf{reiniciar y ejecutar el kernel}$ para ver que el archivo se compila sin errores
# * enviar el archivo jupyter sin anexos antes de las 10.10am del 04.03.2022 a mi dirección de correo electrónico: michal.hemmerling@udea.edu.co

# %% [markdown]
# # Ejercicio

# %% [markdown]
# Bajo ciertas condiciones, los dispositivos ópticos como los láseres pueden mostrar un comportamiento complejo en el perfil del rayo de luz.
#
#
# <table><tr>
# <td> <img src="nonlinear_behaviour.png" width="600" /> </td>
# </tr></table>
#
# Para un dispositivo óptico particular que consiste en un medio no lineal dentro de una cavidad óptica, esto sólo ocurre cuando la intensidad I se encuentra dentro de un cierto rango que está dado por la ecuación:
#
# $$f(x)=(x+1)^2 - c(x-1) < 0 $$
#
# donde $x$ es la intensidad del campo eléctrico y $c$ es la fuerza de la absorción del
# medio no lineal.

# %% [markdown]
# ## 1.
# Cree una función llamada `f_cost` que reciba dos parámetros (x,c) y solo devuelva la función f(x) como se mencionó anteriormente.

# %%
# tu codigo:
def f_cost(x,c):
  return (x+1)**2-c*(x-1)

# %% [markdown]
# ## 2.
# Usando funcion `f_cost` haz un gráfico con cuatro curvas para c=5,10,15,20 y con x entre -10,20 (50 puntos)
# * hacer que cada curva sea de un color diferente
# * añadir etiquetas

# %%
# tu codigo:
import numpy as np
import matplotlib.pyplot as plt

c=[5,10,15,20]
x=np.linspace(-10,20,50)
c5=f_cost(x,c[0])
c10=f_cost(x,c[1])
c15=f_cost(x,c[2])
c20=f_cost(x,c[3])

plt.plot(x,c5, 'b', label='c=5')
plt.plot(x,c10, 'r',  label='c=10')
plt.plot(x,c15, 'g',  label='c=15')
plt.plot(x,c20, 'y',  label='c=20')

plt.title('curvas para diferentes valores de c')
plt.xlabel('x')
plt.ylabel('c')
plt.legend()
plt.grid()

# %% [markdown]
# ## 2a. Para cual `c` esta funcion no tiene raices?

# %%
# tu respuesta
import scipy.optimize as optimize

def root_finding(f_cost,start,c): 
    try:
        root = optimize.newton(f_cost, start,args=(c,))
    except:
        root='dont have root'
    return root

# %%
root5=root_finding(f_cost, start=-5, c=c[0])
root10=root_finding(f_cost, start=-5, c=c[1])
root15=root_finding(f_cost, start=-5, c=c[2])
root20=root_finding(f_cost, start=-5, c=c[3])

print(f'Las raíces cuando c=5 {root5}')
print(f'Las raíces cuando c=10 {root10}')
print(f'Las raíces cuando c=15 {root15}')
print(f'Las raíces cuando c=20 {root20}')
# Out:
# Las raíces cuando c=5 dont have root
# Las raíces cuando c=10 1.7639320225002106
# Las raíces cuando c=15 1.376524617020201
# Las raíces cuando c=20 1.2540333075851662

# %% [markdown]
# Usando el try except, nos damos cuenta que para un  valor de c=5 no hay raíces.

# %% [markdown]
# ## 3.
# Cree una función llamada `root_finding()` que devuelva el valor de la raíz (si existiera) para cada parametro `c` (pense `Newton` o `bisecion`). Usando esta funcion vamos a buscar primero raiz izquierda y despues raiz derecha.

# %%
def root_finding(f_cost,start,c): 
    try:
        root = optimize.newton(f_cost, start,args=(c,))
    except:
        root=np.nan
    return root

# %% [markdown]
# ## 4a.
# Primero vamos a mirar el comportamiento de raiz de lado izquierda: Defina el vector `c_vec` que contiene 50 valores de 5 a 100. En el loop, llame a la función `root_finding()` para cada valor `c` en el vector `c_vec`. Guarda los resultados en variable `left_roots`

# %%
# tu codigo:
c_vec=np.linspace(5,100,50)
left_roots=[]
for c in c_vec:
  left_roots.append(root_finding(f_cost,-5,c))

# %% [markdown]
# ## 4b
# Hacer un gráfico de raíz izquierda vs c

# %%
# tu codigo:

plt.plot(left_roots, c_vec)
plt.title('left roots vs c')
plt.xlabel('roots')
plt.ylabel('c')
plt.grid()

# %% [markdown]
# ## 5a.
# Ahora vamos a mirar el comportamiento de raiz de lado derecha: Defina el vector `c_vec` que contiene 50 valores de 5 a 100. En el loop, llame a la función `root_finding()` para cada valor `c` en el vector `c_vec`. Guarda los resultados en variable `right_roots`.

# %%
# tu codigo:

right_roots=[]
for c in c_vec:
  right_roots.append(root_finding(f_cost,50,c))

# %% [markdown]
# ## 5b
# * Hacer un gráfico de raíz derecha vs c

# %%
# tu codigo:

plt.plot(right_roots, c_vec)
plt.title('right roots vs c')
plt.xlabel('roots')
plt.ylabel('c')
plt.grid()

# %% [markdown]
# ## 6.
# Pregunta:
# * este cierto *rango* para cual se obtiene un comportamiento complejo esta convergente o divergente cuando `c` es creciente
# * si este rango esta convergiendo, ¿a qué valor?
# * si este rango esta divergente, como esta divergente (lineal, cuadrático, diferente)

# %% [markdown]
# <b>Respuesta</b>: Cómo se puede observar en el gráfico titulado 'left roots vs c', tenemos un comportamiento convergente cuando c crece, se observa que las raíces de la parte derecha ('left roots) y su comportamiento convergen a un valor cercano a 2.0.
#
# Para el caso de las raíces de la derecha, en el gráfico 'right roots vs c', se nota que se tiene un comportamiento divergente de manera lineal cuando c crece. Notemos que la gráfica nos da una línea recta.

# %% [markdown]
# # Feedback:
#
# `Correct implementation of the f_cost function + labeled plot 	  (max 2.0p):	2.0p`
# `Correct implementation of the root finding function 		       (max 2.0p):	2.0p`
# `Correct result of the evolution of the left roots (+ plot)	     (max 2.0p):	2.0p`
# `Correct result of the evolution of the right roots (+ plot)	    (max 2.0p):	2.0p`
# `Correct conclusion of the range behaviour			              (max 2.0p):	1.0p`
#
# `- Total:                                                          (max 10.0p):   9.0p`
#
# #### Comments:
# - "comportamiento convergen a un valor cercano a 2.0" - Incorrect (the function converges to value 1)
